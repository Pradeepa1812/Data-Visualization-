# %% [markdown]
# # Finance Project

# %% [markdown]
# # Libraries

# %%
from pandas_datareader import data,wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# # Using datareader we read the data from online

# %%
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)
BAC=data.get_data_yahoo("BAC",start,end)
GS=data.get_data_yahoo("GS",start,end)
C=data.get_data_yahoo("C",start,end)
JPM=data.get_data_yahoo("JPM",start,end)
MS=data.get_data_yahoo("MS",start,end)
WFC=data.get_data_yahoo("WFC",start,end)

# %%
C
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994   1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988   1870900.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012   1143100.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012   1370200.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994   1680700.0
# ...                ...         ...         ...         ...         ...
# 2015-12-24   52.970001   52.450001   52.480000   52.709999   4671200.0
# 2015-12-28   52.570000   51.959999   52.570000   52.380001   8761700.0
# 2015-12-29   53.220001   52.740002   52.759998   52.980000  10155100.0
# 2015-12-30   52.939999   52.250000   52.840000   52.299999   8763300.0
# 2015-12-31   52.389999   51.750000   52.070000   51.750000  11281800.0
#
#              Adj Close
# Date
# 2006-01-03  388.105530
# 2006-01-04  380.940277
# 2006-01-05  382.830109
# ...

# %% [markdown]
# # Create a list of the tickers in alphabetical order

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
# # Concat

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %% [markdown]
# # setting the column name

# %%
bank_stocks.columns.names=['Bank Tickers','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Tickers        BAC                                               \
# Stock Info         High        Low       Open      Close      Volume
# Date
# 2006-01-03    47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04    47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05    46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06    46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09    46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Tickers                      C                                      ...  \
# Stock Info    Adj Close        High         Low        Open       Close  ...
# Date                                                                     ...
# 2006-01-03    35.298687  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04    34.923801  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05    34.968796  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # Max  Open price for each bank_stock throughout the time period

# %%
#for tick in tickers:
#  print(tick,bank_stocks[tick]['Open'].max())
    
bank_stocks.xs(key='Open',axis=1,level='Stock Info').max()
# Out:
# Bank Tickers
# BAC     55.040001
# C      566.000000
# GS     243.550003
# JPM     70.190002
# MS      90.769997
# WFC     58.730000
# dtype: float64

# %% [markdown]
# # creating new empty dataframe called returns

# %%
returns=pd.DataFrame()

# %% [markdown]
# # we can use pandas pct_change() method  on the Open column to create a column representing this return value

# %%
for tick in tickers:
    returns[tick+'Return']=bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %% [markdown]
# # PairPlot

# %%
import seaborn as sns

# %%
sns.pairplot(returns[1:],palette='Viridis')

# %%
returns.sort_index(axis=1).head(3)
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110

# %%
returns.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACReturn    0.036647
# CReturn      0.038672
# GSReturn     0.025390
# JPMReturn    0.027667
# MSReturn     0.037819
# WFCReturn    0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %% [markdown]
# # Visualization Libraries

# %%
import matplotlib.pyplot as plt
import cufflinks as cf
import plotly 
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
sns.set_style('whitegrid')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(18,5))
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MSReturn'],color='maroon',bins=30)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(18,5))
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['CReturn'],color='green',bins=60)

# %%
import plotly as py

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(19,4))
plt.legend()
#bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot(figsize=(19,6))

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="843564f9-08a1-4c6a-859d-7c0fa8f2d705" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("843564f9-08a1-4c6a-859d-7c0fa8f2d705")) {
#                     Plotly.newPlot(
#                         '843564f9-08a1-4c6a-859d-7c0fa8f2d705',
# ...

# %% [markdown]
# # Average

# %%
BAC['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot(label='30 days')
BAC['Close'].loc['2008-01-01':'2008-12-31'].plot(label='BAC close')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr=bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()

# %%
close_corr.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="256a59f5-591d-4eda-97ba-90b7228170b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("256a59f5-591d-4eda-97ba-90b7228170b7")) {
#                     Plotly.newPlot(
#                         '256a59f5-591d-4eda-97ba-90b7228170b7',
# ...

# %%
close_corr.iplot(kind='heatmap')
# Out:
# <div>
#
#
#             <div id="389a7d6c-9dfb-4119-929c-dfa1c7f924e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("389a7d6c-9dfb-4119-929c-dfa1c7f924e0")) {
#                     Plotly.newPlot(
#                         '389a7d6c-9dfb-4119-929c-dfa1c7f924e0',
# ...

# %%
d=BAC[['Open','Close','Low','High']].loc['2008-01-01':'2008-12-31']

# %%
d.iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="016135ae-c6b7-4477-836d-eba278776f29" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("016135ae-c6b7-4477-836d-eba278776f29")) {
#                     Plotly.newPlot(
#                         '016135ae-c6b7-4477-836d-eba278776f29',
# ...

# %% [markdown]
# # Technical plot Analysis for the year 2015

# %%
MS['Close'].loc['2015-01-01':'2015-12-31'].ta_plot(study='sma',periods=[13,65,98])
# Out:
# <div>
#
#
#             <div id="4514fc23-f4da-4a4f-b2e9-634debff3416" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4514fc23-f4da-4a4f-b2e9-634debff3416")) {
#                     Plotly.newPlot(
#                         '4514fc23-f4da-4a4f-b2e9-634debff3416',
# ...

# %%
C['Close'].loc['2015-01-01':'2015-12-31'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="d957da73-ed91-43e8-9b34-c015ffd23eb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d957da73-ed91-43e8-9b34-c015ffd23eb6")) {
#                     Plotly.newPlot(
#                         'd957da73-ed91-43e8-9b34-c015ffd23eb6',
# ...
